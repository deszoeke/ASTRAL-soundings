# %%
# Code to read and process IMD soundings for ASTraL IOP1
# Alex Kinsella, August 2024, modified from code by Simon de Szoeke for ASraL Pilot, June 2023
# Added level 1 QC checks from code by Jayesh Phadtare
# Input: Raw IMD txt files
# Ouput: Level 1 QCed netcdf files

# %%
env_path = "../.."
data_path = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/"
# Out:
# "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/"

# %%
#cd("~/Projects/ASTRAL/soundings/src/")

# activate the environment
# an environment is just a path with Manifest.toml and Project.toml
using Pkg; Pkg.activate(env_path)

using Revise
#using Regex
using CSV, DataFrames
using Interpolations
using Dates
using PyPlot
using NCDatasets
# Out:
#   Activating project at `~/Documents/WHOI/Projects/ASTraL/Code/ASTRAL-soundings`
# WARNING: Method definition xparse(Type{T}, AbstractString, Any, Any, Any) where {T<:InlineStrings.InlineString} in module InlineStrings at /Users/kinsella/.julia/packages/InlineStrings/rlLZO/src/InlineStrings.jl:865 overwritten in module ParsersExt at /Users/kinsella/.julia/packages/InlineStrings/79NvI/ext/ParsersExt.jl:5.
# ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# ┌ Error: Error during loading of extension ParsersExt of InlineStrings, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    Declaring __precompile__(false) is not allowed in files that are being precompiled.
# │    Stacktrace:
# │      [1] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base ./loading.jl:1999
# │      [2] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base ./loading.jl:1812
# │      [3] #invoke_in_world#3
# │        @ ./essentials.jl:926 [inlined]
# │      [4] invoke_in_world
# │        @ ./essentials.jl:923 [inlined]
# │      [5] _require_prelocked
# │        @ ./loading.jl:1803 [inlined]
# │      [6] _require_prelocked
# │        @ ./loading.jl:1802 [inlined]
# │      [7] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base ./loading.jl:1295
# │      [8] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base ./loading.jl:1330
# │      [9] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base ./loading.jl:1164
# │     [10] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base ./loading.jl:1819
# │     [11] #invoke_in_world#3
# │        @ ./essentials.jl:926 [inlined]
# │     [12] invoke_in_world
# │        @ ./essentials.jl:923 [inlined]
# │     [13] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base ./loading.jl:1803
# │     [14] macro expansion
# │        @ ./loading.jl:1790 [inlined]
# │     [15] macro expansion
# │        @ ./lock.jl:267 [inlined]
# │     [16] __require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:1753
# │     [17] #invoke_in_world#3
# │        @ ./essentials.jl:926 [inlined]
# │     [18] invoke_in_world
# │        @ ./essentials.jl:923 [inlined]
# │     [19] require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:1746
# │     [20] include
# │        @ ./Base.jl:495 [inlined]
# │     [21] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base ./loading.jl:2222
# │     [22] top-level scope
# │        @ stdin:3
# │     [23] eval
# │        @ ./boot.jl:385 [inlined]
# │     [24] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base ./loading.jl:2076
# │     [25] include_string
# │        @ ./loading.jl:2086 [inlined]
# │     [26] exec_options(opts::Base.JLOptions)
# │        @ Base ./client.jl:316
# │     [27] _start()
# │        @ Base ./client.jl:552
# └ @ Base loading.jl:1301

# %%
#data_path = "../data/"
CamelStations = ["Ahmedabad","Bhubaneswar","Chennai","Karaikal","Kochi","Kolkata","Minicoy","PortBlair","Pune","SantaCruz","Visakhapatnam"]

"Parse the various date formats in the file names. Only works for 3-letter month (or May)."
function imd_file_date(fn)
    if fn[1:6]=="43150-" && all(isnumeric, fn[[7:14; 16:17]]) # 43150 Visakhap. WMO station ID
        dt = Dates.DateTime(fn[7:17], "yyyymmdd-HH")
    elseif fn[10:12]=="VSK" && all(isnumeric, fn[[1:2; 6:9]])  # Visakhap.
        dt = Dates.DateTime(fn[1:9], "ddUUUyyyy")
    elseif all(isnumeric, fn[[1:8; 10:11]])
        dt = Dates.DateTime(fn[1:11], "yyyymmdd-HH")
    elseif all(isnumeric, fn[[1:4; 6:7; 9:10; 12:13; 15:16; 18:19]])
        dt = Dates.DateTime(fn[1:13], "yyyy-mm-dd_HH")
    else
        # expect undelimited 3-letter month
        if all(isnumeric, fn[[1:2; 6:7]])
            if isletter(fn[8])
                dt = DateTime( 2000+year(DateTime(fn[6:7], "yy")),
                    month(DateTime(fn[3:5], "U")),
                    day(DateTime(fn[1:2], "d")) )
            elseif all(isnumeric, fn[8:9])
                dt = DateTime( year(DateTime(fn[6:9], "yyyy")),
                    month(DateTime(fn[3:5], "U")),
                    day(DateTime(fn[1:2], "d")) )
            end
        end
    end
    return dt
end


"count unique soundings from each station, return maximum"
function count_max_unique_soundings(stationnames)
    nts = zeros(Int32, length(stationnames))
    
    for (sj, station) in enumerate(stationnames)
        # read standard named files in the station's directory
        files = soundingfiles(station)
        # deduplicate sounding times
        fdt = imd_file_date.(files)
        fdt12 = round.(fdt, Dates.Hour(12))
        ui = uniqueidx(fdt12)
        fdt[ui] # exact datetimes with duplicates removed
        ord = sortperm(fdt[ui]) # guarantees ascending order
        nts[sj] = length(ui)
        # @show station, nts[sj]
    end
    
    nt = maximum(nts)
end

soundingfiles(stationdir; data_path=data_path) = filter(x -> occursin(r"(?i)(Standard_Summary|Standard-Summary|Standard Summary).*(\.txt)$(?-i)",x),
                   readdir(joinpath(data_path, stationdir)) ) 

uniqueidx(v) = unique(i -> v[i], eachindex(v))

# Interpolation methods
# Pressure is irregular and different for each sounding time.

"dv converts Datetimes to numeric values for Interpolations."
dv(dt, offset=DateTime(2019,3,1)) = Dates.value(dt - offset)

# interpolation functions
function itp_sparse(x::Vector, p::Vector)
    # knot-vectors must be unique and sorted in increasing order
    ind = sortperm(p)
    ii = isfinite.(p[ind])
    extrapolate( interpolate( (p[ind][ii],), x[ind][ii], Gridded(Linear()) ), NaN )
end

"Filter missing data from the input sounding before interpolating."
function itp(x::Vector, p::Vector)
    # knot-vectors must be unique and sorted in increasing order
    ind = sortperm(p)
    ii = isfinite.(p[ind] .+ x[ind]) # .& .!ismissing.(p[ind] .+ x[ind])
    extrapolate( interpolate( (p[ind][ii],), x[ind][ii], Gridded(Linear()) ), NaN )
end

"rectangular interval averaging onto a decreasing pressure coordinate"
function pavg(x::Vector, p::Vector; plevs=1020.0:-5.0:0.0)
    s1 = zeros(Float64, size(plevs))
    # s2 = zeros(Float64, size(p))
    ns = zeros(Float64, size(plevs))
    
    for i in eachindex(p)
        j = findfirst(x -> x < p[i], plevs) # j indexes plevs
        s1[j] += isfinite(x[i]) ? x[i] : 0
        # s2[j] += x[i]^2
        ns[j] += 1.0*isfinite(x[i])
    end
    
    s1 ./ ns # mean
end

# pressure levels to interploate to
dp = 5.0
plevs = 1020.0:-dp:0.0

"single-character replacer handles tabs and \u00b0 degree character °"
stripjunk(f) = IOBuffer(replace(read(f), UInt8('\t') => UInt8(' '), UInt16('\u00b0') => UInt8('d')) )

"read the file and return a DataFrame"
#function read_sonde( station, file; header=hdrs(station,file) )
function read_sonde( file )
    open( file, "r" ) do io
        lines = readlines( io )
        hdr = findfirst(x-> ~isempty(x)&&length(x)>4&&strip(x)[1:5]=="Time,", lines)
        if isnothing(hdr)
            hdr = length(lines)+1
        end
        footskip=0
        if lines[end][1]=='-'
            footskip=1
            if lines[end-1][1]=='-'
                footskip=2
            end
        end
        CSV.read( stripjunk( file ),
            DataFrame, delim=",", stripwhitespace=true, ignorerepeated=true, header=hdr[1],footerskip=footskip)
    end
end

"extract column data by name"
function get_sounding_cols(df, station)
    if isempty(df)
        # p = [missing]
        # T = [missing]
        # Td = [missing]
        # rh= [missing]
        # z = [missing]
        # wspd = [missing]
        # wdir = [missing]
        p = []
        T = []
        Td = []
        rh= []
        z = []
        wspd = []
        wdir = []
    else
        if in(station, ["mangalore", "bhubaneswar", "visakhapatnam", "portblair"])
            if "P(hPa)" in names(df)
                p = df[!,"P(hPa)"][:]
                T = df[!,"T(C)"][:]
                Td = df[!,"Dew(C)"][:]
                rh = df[!,"U(%)"][:]
                z = df[!,"Geo(gpm)"][:]
                wspd = df[!,"Wspd(m/s)"][:]
                wdir = df[!,"Wdir(d)"][:]
            elseif "p(hPa)" in names(df) # slightly different keys
                p = df[!,"p(hPa)"][:]
                rh = df[!,"U(%)"][:]
                z = df[!,"Geo(gpm)"][:]
                wspd = df[!,"Wspd(m/s)"][:]
                if "T(dC)" in names(df)
                    T = df[!,"T(dC)"][:]
                    Td = df[!,"Dew(dC)"][:]
                    wdir = df[!,"Wdir(d)"][:]
                elseif "T(Deg.C)" in names(df) # another variation
                    T = df[!,"T(Deg.C)"][:]
                    Td = df[!,"Dew(Deg.C)"][:]
                    wdir = df[!,"Wdir(Deg)"][:]
                end
            end
        else # slightly different keys
            p = df[!,"p(hPa)"][:]
            rh = df[!,"U(%)"][:]
            z = df[!,"Geo(gpm)"][:]
            wspd = df[!,"Wspd(m/s)"][:]
            if "T(dC)" in names(df)
                T = df[!,"T(dC)"][:]
                Td = df[!,"Dew(dC)"][:]
                wdir = df[!,"Wdir(d)"][:]
            elseif "T(Deg.C)" in names(df) # another variation
                T = df[!,"T(Deg.C)"][:]
                Td = df[!,"Dew(Deg.C)"][:]
                wdir = df[!,"Wdir(Deg)"][:]
            end

        end
    end
    u = -wspd .* sin.(pi/180.0*wdir)
    v = -wspd .* cos.(pi/180.0*wdir)
    
    return p, T,Td, rh,z, wspd,wdir, u,v
end

"read and grid IMD soundings to pressure levels."
function grid_imd_soundings!( time, T, Td, rh, z, u, v; 
                              plevs=plevs, stationnames=stationnames, data_path=data_path )
    for (sj, station) in enumerate(stationnames)
        @show station
        # read standard named files in the station's directory
        files = soundingfiles(station)
        # sj += 1 # gridded station index
        # deduplicate sounding times
        fdt = imd_file_date.(files)
        fdt12 = round.(fdt, Dates.Hour(12))
        ui = uniqueidx(fdt12)
        fdt[ui] # exact datetimes with duplicates removed
        ord = sortperm(fdt[ui]) # guarantees ascending order
        #collect(zip( files[ui[ord]]], fdt[ui[ord]] ))
        
        tj = 0
        for ti in ui[ord]
            fn = joinpath(data_path, station, files[ti])
            @show fn
            df = read_sonde( joinpath(data_path, station, files[ti]) )
            if !isempty(df)
                # extract ungridded hi-res data
                p_, T_,Td_, rh_,z_, wspd_,wdir_, u_,v_ = get_sounding_cols(df, station)
                # avg variables at the next time level
                tj += 1
                # update arrays in place
                time[sj,tj] = fdt[ti]
                T[  :, sj, tj] .= pavg(T_ , p_, plevs=plevs)
                Td[ :, sj, tj] .= pavg(Td_, p_, plevs=plevs)
                rh[ :, sj, tj] .= pavg(rh_, p_, plevs=plevs)
                z[  :, sj, tj] .= pavg(z_ , p_, plevs=plevs)
                u[  :, sj, tj] .= pavg(u_ , p_, plevs=plevs)
                v[  :, sj, tj] .= pavg(v_ , p_, plevs=plevs)
            else
                tj += 1
                time[sj,tj] =fdt[ti]
                # leave an empty sounding when missing
            end
        end
    end
    return # nothing
end

"output days from offset"
mpldate(timestamp, offset=DateTime(2023,4,30,0,0,0)) = Dates.value(timestamp-offset)/1000/60/60/24
#invmpldate( mlpd, offset=DateTime(2023,4,30,0,0,0) ) = mpldate+Dates.value(offset)/1000/60/60/24
mplday(d; offset=Date(2023,4,30)) = day(Day(d) + offset) # ticks

"Update plot all u,rh sounding timeheight profiles and put to APL."
function plot_timeheights( time, T, Td, rh, z, u, v )
    # count times at each station
    nts = sum(time.>DateTime(1000), dims=2)
    for sj in 1:size(time)[1]
        @show sj
        @show mpldate.(time[sj,1:nts[sj]])
        clf()
        subplot(2,1,1)
        pcolormesh( mpldate.(time[sj,1:nts[sj]]), plevs, u[:,sj,1:nts[sj]], vmin=-10, vmax=10, cmap=ColorMap("RdYlBu_r") )
        ylim(1000, 100)
        ylabel("u (m/s)")
        xtl,~ = xticks()
        xticks( xtl, mplday.(xtl,offset=Date(2023,4,30)) )
        colorbar()
        title(CamelStations[sj])
    
        subplot(2,1,2)
        pcolormesh( mpldate.(time[sj,1:nts[sj]]), plevs, rh[:,sj,1:nts[sj]], cmap=ColorMap("RdYlBu_r"))
        ylim(1000, 100)
        ylabel("RH (%)")
        xtl,~ = xticks()
        xticks( xtl, mplday.(xtl,offset=Date(2023,4,30)) )
        colorbar()
        xlabel(Dates.format(time[sj,1], "yyyy U"))
    
        figfile = "../plot/$(CamelStations[sj])_u_rh.svg"
        savefig( figfile )
        #put_file_apl( figfile )
    end
end

"Write out pressure-gridded sonde data. Push new files to APL. Let old files stand."
function write_new_grid_sondes( time, T, Td, rh, z, u, v; stationnames )
    # count times at each station
    nts = sum(time.>DateTime(1000), dims=2)
    for (sj, station) in enumerate(stationnames)
        for tj in 1:nts[sj]
            fileout = joinpath(data_path,"grid_sondes/", Dates.format(time[sj,tj], "yyyymmdd-HH")*"_$(CamelStations[sj]).csv")
            fileoutnc = joinpath(data_path,"grid_sondes/", Dates.format(time[sj,tj], "yyyymmdd-HH")*"_$(CamelStations[sj]).nc")
            if !isfile(fileout)
                # @show fileout
                dfo = DataFrame(  p=plevs,
                                  T=T[  :, sj, tj],
                                  Td=Td[:, sj, tj],
                                  rh=rh[:, sj, tj],
                                  z=z[  :, sj, tj],
                                  u=u[  :, sj, tj],
                                  v=v[  :, sj, tj]  )
                CSV.write( fileout, dfo )

                ds = NCDataset(fileoutnc,"c")
                ds.attrib["time"] = Dates.format(time[sj,tj], "yyyymmdd-HH")

                defDim(ds,"p",length(plevs))
                
                
                # Define the variables
                Tvar=defVar(ds,"T",T[  :, sj, tj],("p",))
                Tdvar=defVar(ds,"Td",Td[:, sj, tj],("p",))
                rhvar=defVar(ds,"rh",rh[:, sj, tj],("p",))
                zvar=defVar(ds,"z",z[  :, sj, tj],("p",))
                uvar=defVar(ds,"u",u[  :, sj, tj],("p",))
                vvar=defVar(ds,"v",v[  :, sj, tj],("p",))    
                pvar=defVar(ds,"p",plevs,("p",))             
                
                # write attributes
                Tvar.attrib["units"] = "deg C"
                Tdvar.attrib["units"] = "deg C"
                rhvar.attrib["units"] = "%"
                zvar.attrib["units"] = "m"
                uvar.attrib["units"] = "m/s"
                vvar.attrib["units"] = "m/s"
                pvar.attrib["units"] = "mb"

                close(ds)

                #put_file_apl( fileout )
            end
        end
    end
end
# Out:
# write_new_grid_sondes

# %%
# do
# a big loop to read all sounding files, interpolate data to consistent levels
# output gridded files, and make plots

# reiterate parameters for paths, names, and gridding
#data_path = "../data/"
plevs = 1020.0:-5.0:0.0
CamelStations = ["Ahmedabad","Bhubaneswar","Chennai","Karaikal","Kochi","Kolkata","Mangalore","Minicoy","PortBlair","Pune","SantaCruz","Visakhapatnam"]
stationnames = lowercase.(CamelStations)

# allocate gridded data arrays (pressure, location, launch time)
nt = count_max_unique_soundings(stationnames)
# nt = 80 # allow for longest station mangalore?(37), extend & trim off extra later
times = zeros(DateTime, length(stationnames), nt)
T  = NaN.+zeros(Float64, length(plevs), length(stationnames), nt)
Td = NaN.+zeros(Float64, length(plevs), length(stationnames), nt)
rh = NaN.+zeros(Float64, length(plevs), length(stationnames), nt)
z  = NaN.+zeros(Float64, length(plevs), length(stationnames), nt)
u  = NaN.+zeros(Float64, length(plevs), length(stationnames), nt)
v  = NaN.+zeros(Float64, length(plevs), length(stationnames), nt)

grid_imd_soundings!( times, T, Td, rh, z, u, v; plevs=plevs, stationnames=stationnames, data_path=data_path )

#plot_timeheights( times, T, Td, rh, z, u, v )
write_new_grid_sondes( times, T, Td, rh, z, u, v; stationnames )
# Out:
# station = "ahmedabad"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240415-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240416-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240417-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240418-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240419-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240420-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240421-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240422-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240423-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240424-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240425-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240426-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240427-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240428-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240429-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240430-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240501-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240502-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240503-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240504-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240505-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240506-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240507-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240508-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240510-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240511-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240512-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240513-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240514-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240515-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240516-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240517-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240518-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240519-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240520-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240521-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240522-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240523-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240524-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240525-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240526-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240527-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240528-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240529-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240530-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240531-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240601-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240602-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/ahmedabad/20240603-00-Standard_Summary.txt"
# station = "bhubaneswar"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240506-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240507-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240508-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240509-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240510-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240511-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240512-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240513-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240514-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240515-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240516-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240521-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240522-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240522-11-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240523-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240523-11-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240524-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240524-11-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240525-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240525-11-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240526-11-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240527-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240528-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240529-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240530-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240601-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240602-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/bhubaneswar/20240603-00-Standard-Summary.txt"
# station = "chennai"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240422-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240423-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240424-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240426-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240501-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240502-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240503-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240504-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240505-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240506-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240507-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240508-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240509-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240510-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240511-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240512-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240513-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240514-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240515-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240516-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240518-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240520-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240521-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240522-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240523-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240524-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/2024-05-25_23-01-59_Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/2024-05-26_23-01-19_Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/2024-05-27_23-02-28_Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/2024-05-28_23-02-54_Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/2024-05-29_23-01-12_Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/2024-05-30_23-01-55_Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240601-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240602-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/chennai/20240603-00-Standard Summary.txt"
# station = "karaikal"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240413-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240414-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240415-00-Standard Summary-karaikal.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240416-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240417-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240418-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240418-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240419-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240420-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240420-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240421-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240422-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240422-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240424-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240425-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240426-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240426-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240427-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240428-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240429-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240430-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240430-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240501-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240502-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240502-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240503-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240504-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240504-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240505-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240506-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240507-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240508-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240508-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240509-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240510-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240511-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240512-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240513-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240514-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240515-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240516-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240517-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240518-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240519-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240520-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240521-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240522-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240523-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240524-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240525-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240526-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240527-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240528-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240529-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240530-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240531-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/karaikal/20240601-00-Standard Summary.txt"
# station = "kochi"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240415-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240416-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240417-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240417-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240418-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240419-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240420-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240421-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240421-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240422-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240423-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240424-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240424-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240425-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240426-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240427-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240428-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240429-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240430-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240501-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240502-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240503-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240504-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240505-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240505-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240506-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240507-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240508-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240509-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240510-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240510-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240511-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240512-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240513-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240514-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240515-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240516-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240517-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240518-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240519-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240520-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240521-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240522-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240522-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240523-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240524-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240525-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240526-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240527-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240529-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240530-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240531-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240601-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240602-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kochi/20240603-00-Standard Summary.txt"
# station = "kolkata"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240415-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240416-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240417-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240418-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240420-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240421-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240422-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240423-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240424-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240425-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240427-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240428-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240429-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240430-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240501-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240502-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240502-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240503-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240504-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240505-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240506-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240506-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240507-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240508-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240509-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240510-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240511-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240512-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240513-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240514-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240515-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240516-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240517-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240518-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240519-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240520-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240521-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240522-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240523-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240524-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240525-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240526-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240528-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240529-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240530-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240531-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240601-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240602-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/kolkata/20240603-00-Standard Summary.txt"
# station = "mangalore"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240414-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240415-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240416-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240417-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240418-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240419-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240420-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240421-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240422-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240423-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240424-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240425-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240426-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240427-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240428-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240429-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240430-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240501-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240502-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240503-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240505-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240526-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240527-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240528-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240529-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240530-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/mangalore/20240531-00-Standard Summary.txt"
# station = "minicoy"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240415-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240416-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240417-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240418-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240419-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240420-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240421-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240422-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240423-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240424-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240425-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240426-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240427-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240428-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240429-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240430-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240501-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240502-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240503-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240504-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240505-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240506-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240507-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240508-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240509-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240510-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240511-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240512-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240513-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240514-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240515-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240516-00-Standard_Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/minicoy/20240517-00-Standard_Summary.txt"
# station = "portblair"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/portblair/20240526-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/portblair/20240527-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/portblair/20240528-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/portblair/20240529-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/portblair/20240530-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/portblair/20240531-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/portblair/20240601-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/portblair/20240602-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/portblair/20240603-00-Standard-Summary.txt"
# station = "pune"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240415-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240417-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240418-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240418-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240419-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240422-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240423-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240424-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240424-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240425-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240426-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240427-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240428-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240429-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240430-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240501-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240502-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240503-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240504-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240505-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240506-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240507-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240508-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240509-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240510-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240511-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240512-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240513-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240514-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240515-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240516-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240517-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240517-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240518-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240519-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240520-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240521-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240523-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240524-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240525-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240527-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240528-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240529-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240529-12-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240530-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240531-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240601-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240602-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/pune/20240603-00-Standard Summary.txt"
# station = "santacruz"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240507-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240508-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240509-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240510-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240511-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240512-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240513-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240514-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240515-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240516-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240517-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240518-00-Standard Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/santacruz/20240519-00-Standard Summary.txt"
# station = "visakhapatnam"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240414-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240416-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240418-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240419-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240420-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240421-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240423-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240424-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240425-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240426-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240427-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240428-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240429-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240501-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240502-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240504-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240505-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240506-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240507-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240508-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240509-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240510-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240511-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240512-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240513-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240514-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240515-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240516-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240517-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240518-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240519-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240520-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240521-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240522-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240524-11-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240525-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240525-11-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240526-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240526-11-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240531-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240601-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240602-00-Standard-Summary.txt"
# fn = "/Users/kinsella/Documents/WHOI/Projects/ASTraL/2024_IOP1/ASTRAL-soundings/data/visakhapatnam/20240603-00-Standard-Summary.txt"

# %%
"Update plot all u,rh sounding timeheight profiles and put to APL."
function plot_timeheights( time, T, Td, rh, z, u, v )
    # count times at each station
    nts = sum(time.>DateTime(1000), dims=2)
    for sj in 1:size(time)[1]
        @show sj
        @show mpldate.(time[sj,1:nts[sj]])
        clf()
        subplot(2,1,1)
        pcolormesh( mpldate.(time[sj,1:nts[sj]]), plevs, u[:,sj,1:nts[sj]], vmin=-10, vmax=10, cmap=ColorMap("RdYlBu_r") )
        ylim(1000, 100)
        ylabel("u (m/s)")
        xtl,~ = xticks()
        xticks( xtl, mplday.(xtl,offset=Date(2023,4,30)) )
        colorbar()
        title(CamelStations[sj])
    
        subplot(2,1,2)
        pcolormesh( mpldate.(time[sj,1:nts[sj]]), plevs, rh[:,sj,1:nts[sj]], cmap=ColorMap("RdYlBu_r"))
        ylim(1000, 100)
        ylabel("RH (%)")
        xtl,~ = xticks()
        xticks( xtl, mplday.(xtl,offset=Date(2023,4,30)) )
        colorbar()
        xlabel(Dates.format(time[sj,1], "yyyy U"))
    
        figfile = "../plot/$(CamelStations[sj])_u_rh.svg"
        savefig( figfile )
        #put_file_apl( figfile )
    end
end
# Out:
# plot_timeheights
